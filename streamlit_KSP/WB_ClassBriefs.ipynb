# %%
wb_briefs = {
    'Digital Services': "Digital Services 카테고리의 사업들은 정부 공공서비스와 행정 전반을 디지털화하는 데 초점을 맞추고 있다. 전자조달 시스템, 전자결제·세금 시스템, 통합 재정관리 및 자산관리 시스템, 온라인 포털 등 다양한 e-정부 플랫폼을 구축하거나 고도화하여 행정 효율성과 투명성을 높이고, 시민과 기업의 서비스 접근성을 개선한다. 특히 공공조달 분야에서 중소기업(SME)의 참여 기회를 확대하거나, 빅데이터 등 신기술을 활용한 데이터 기반 의사결정 지원 등 각 사업에서 공통적으로 강조된다. 또한 지속적인 디지털 행정 구현을 위해 제도 개선과 인력 교육 등 역량 강화 방안도 함께 추진한다. 이러한 디지털 서비스 혁신을 통해 정부 운영을 현대화하고 사용자 중심의 데이터 기반 공공서비스 제공을 실현하고자 한다.",
    'Data Infrastructure': "Data Infrastructure 분야의 사업들은 국가 데이터 시스템과 인프라 구축을 통해 정책 결정과 서비스 제공을 개선하는 데 주안점을 두고 있다. 각 사업에서는 정부 통합 데이터센터나 클라우드 기반 e-정부 인프라를 설계하고, 부문별 데이터베이스 구축 및 데이터 표준화 전략을 제시한다. 또한 AI와 빅데이터 기술을 활용하여 재난 예·경보 시스템 개선이나 조세 행정 현대화 등 특정 분야의 문제 해결을 지원하고, 스마트시티와 관광 등 산업 분야의 데이터 활용 전략도 함께 마련한다. 이러한 프로젝트들은 데이터 거버넌스 강화를 위해 법·제도 정비와 기관 간 협력 체계 구축, 전문인력 양성 등을 병행하며, 그 결과 공공 서비스의 효율성 향상, 과학적 의사결정 강화, 재난 대응 및 산업 경쟁력 제고 등의 효과를 기대하고 있다.",
    'Cybersecurity': "Cybersecurity 카테고리에는 디지털 인증체계 강화와 사이버보안 역량 제고를 위한 프로젝트가 포함되어 있다. 라오스에서 추진된 사업의 경우, 전자정부 구현을 뒷받침하기 위해 공공키 기반구조(PKI)를 도입하고 디지털 인증체계 개선 로드맵을 수립하였다. 이 프로젝트에서는 현행 제도와 생태계를 분석하고 한국, 베트남, EU 등의 사례를 비교하여 거버넌스 체계, 기술 표준, 인력 양성 방안을 제안하였으며, 단계별 실행계획(To-Be 모델)을 통해 보안 강화와 디지털 경제 활성화를 도모하였다.",
    'Connectivity': "Connectivity 카테고리에는 통신/방송 인프라의 디지털 전환과 네트워크 연결성 향상을 다루는 프로젝트가 해당된다. 과테말라에서 진행된 사업에서는 아날로그 방송의 디지털 전환을 위한 기본계획과 국가 주파수 할당제(NFAT) 개선을 추진하였다. 700MHz 주파수 대역의 재분배를 통해 모바일 방송 등 신규 서비스 도입 방안을 검토하였으며, 디지털 전환으로 인한 서비스 품질 향상과 '디지털 배당' 주파수의 활용 전략을 제시하였다. 또한 통신·방송 산업 현황과 TV 보급률 등을 분석하고, 한-과테말라 간 정책 연수 등 협력 활동을 통해 현지 역량 강화에도 기여하였다. 이를 통해 디지털 격차 해소와 국민의 정보 접근성 개선 등의 효과를 기대하고 있다.",
    'Digital Industry and Jobs': "Digital Industry and Jobs 카테고리의 사업들은 산업 부문의 디지털 혁신을 촉진하고 일자리 창출에 기여하는 데 초점을 맞추고 있다. 온두라스와 중남미 지역 중소기업의 디지털화 및 e-비즈니스 역량 강화를 위한 정책 수립, 한국-호주 간 AI·5G/6G 등 첨단기술 분야의 파트너십 구축, 베트남 건설 분야의 BIM(건설정보모델링) 적용 체계 지원, 필리핀 축산업의 ICT 기반 품질관리 시스템 도입 등이 추진되었다. 각 사업은 한국의 모범 사례와 국제 기술 표준 공유, 로드맵 및 실행계획 수립을 통해 해당 산업 분야의 생산성 향상과 효율성 제고를 목표로 한다. 이를 통해 디지털 경제 환경 조성과 산업 경쟁력 강화, 나아가 일자리 창출에도 기여하고자 한다."
}
