# %%
wb_briefs = {'Digital Services': '이 부문은 국민 생활 및 산업 전반의 서비스 혁신을 위한 디지털 기술 확산을 다룬다. 프로젝트들은 원격의료, 디지털 방송 전환, 공공조달 서비스 혁신 등 국민 체감형 서비스를 중심으로 한다. 한국의 원격의료·TVWS 인터넷 보급·TUNEPS 시스템 경험을 벤치마킹하여 현지 여건에 맞는 적용 모델을 개발한다. 의료 서비스 접근성 향상, 정보 격차 해소, 행정 투명성 제고가 공통된 목표이다. 특히 농어촌 등 취약지역의 의료 접근성 개선과 공공 서비스 품질 제고가 핵심 성과로 나타난다. 디지털 방송 전환 프로젝트는 주파수 자원의 효율적 활용을 통해 정보 접근권을 확대시킨다. 또한, 지식관리(CoP)·교육훈련·전문인력 양성 체계 구축을 통해 제도의 지속가능성을 확보한다. 서비스 전달체계의 효율화는 국민의 삶의 질 향상과 사회적 포용성 강화를 견인한다. 이 유형은 기술 이전과 제도 설계가 결합된 포용적 디지털 서비스 혁신 모델로 평가된다. 궁극적으로 “디지털 복지사회와 연결성 평등 실현”을 지향한다.', 
 'Digital Economy & Jobs': '이 부문은 디지털 기술을 통한 경제 성장과 일자리 창출을 촉진하는 데 중점을 둔다. 대표적으로 중남미·아시아권 중소기업의 생산성 향상, 무역 활성화, 전자조달 확산이 주요 주제다. 한국의 FDI 유치 경험, KONEPS·전자무역 시스템, IT 기반 생산혁신 정책이 핵심 벤치마킹 모델로 활용된다. 보고서들은 IT 기술을 통해 제조업 효율을 높이고, 물류·수출 절차를 디지털화하여 비용을 절감하는 방법을 제시한다. 특히 전자무역 법제 개선, 표준화된 전자문서 시스템 구축, CRM 기반 지원체계 도입 등 실행 전략이 포함된다. 중소기업의 정보 접근성과 글로벌 시장 진입 장벽을 낮추는 데 초점을 맞추며, 정책적 측면에서는 중복투자 방지 및 효율적 자원 배분을 위한 전문기관의 역할을 강조한다. 디지털 전환을 통한 공정·투명한 경쟁 환경 구축은 고용 확대와 경제 자립의 기반이 된다. 이 유형은 기술혁신을 통한 산업 생태계 확장과 국가 간 디지털 협력을 동시에 견인한다. 결국 “IT를 통한 포용적 성장과 혁신적 산업 구조 고도화”가 궁극적 비전이다.', 
 'Digital Infrastructure & Connectivity': '이 유형의 프로젝트들은 국가의 기반 인프라와 연결성 향상을 핵심 목표로 한다. 주요 사례는 토지관리시스템, 의료정보화, 전자지급결제, 행정 데이터 통합 등이며, 기관 간 정보 불일치와 분산된 시스템 문제를 해결하기 위해 통합 플랫폼을 구축하는 방향으로 진행된다. 예컨대 튀니지의 토지관리시스템 정보화, 한국 KLIS 벤치마킹, 건강보험 DUR·EDI 사례 등은 대표적인 성공 모델이다. 이들은 각국의 공공데이터를 디지털화하고 정확성을 보장하여 행정 절차를 간소화한다. 정보 공유 체계 확립으로 기관별 독립 운영의 한계를 해소하고, 공공업무의 투명성을 강화한다. 또한, 의료·건설·지적 행정 등 사회 기반 부문의 디지털 전환을 통해 국민 체감형 서비스를 확대한다. 사업 수행 과정에서 인력 역량 강화, 표준 프로세스 정립, 기술 교육 체계 구축 등이 병행된다. 결과적으로 행정 비용 절감, 서비스 품질 향상, 국가 간 기술협력 확대라는 다층적 효과를 낳는다. 이 ICT 유형은 “기반 연결성의 고도화와 정보화 인프라의 국제적 정착”을 상징한다.', 
 'Digital Government & Public Administration': '이 유형은 전자정부 시스템 구축과 공공행정 효율화를 통해 국가 운영의 투명성과 안정성을 제고한다. 주요 사례로는 사이버보안 대응체계, 교통 데이터베이스, 공공 인적자원관리(HRMS) 시스템이 있다. 우즈베키스탄의 분산된 보안 체계를 통합하거나, 인도네시아의 교통 데이터 관리 DB를 구축하는 등, 각국의 공공 데이터 관리·표준화·정보공유 부재 문제를 해소하는 방향으로 추진된다. 한국의 법제도 통합, KTDB 구축, ISAC 협력체계, 전자정부 HR 시스템이 핵심 참조 사례이다. 사이버공격 대응 능력 강화와 공공데이터 기반 정책결정 체계는 국가 디지털 전환의 핵심 인프라로 작동한다. 행정 절차의 자동화와 인적자원 관리 효율화는 정부 역량 강화와 부패 방지에도 기여한다. 또한, 민관 협력 기반의 혁신 생태계를 조성하여 정책 집행 속도와 품질을 개선한다. 이 유형은 단순한 전산화가 아니라, 공공 거버넌스의 구조적 혁신을 의미한다. 결과적으로 디지털 신뢰성과 정책 실행력 강화를 통해 “스마트 행정국가”로의 전환을 촉진한다.'}
